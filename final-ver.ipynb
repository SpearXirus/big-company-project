# %%
import seaborn as sns
import pandas as pd
df=sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
setosa=df[df["species"]=="setosa"]

# %%
versicolor=df[df["species"]=="versicolor"]

# %%
virginica=df[df["species"]=="virginica"]

# %%
setosa.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000

# %%
versicolor.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %%
virginica.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
for species in df.species.unique():
  print(species, "======================================")
  print(df[df.species==species].describe())
  print()
# Out:
# setosa ======================================
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000    50.000000
# mean        5.00600     3.428000      1.462000     0.246000
# std         0.35249     0.379064      0.173664     0.105386
# min         4.30000     2.300000      1.000000     0.100000
# 25%         4.80000     3.200000      1.400000     0.200000
# 50%         5.00000     3.400000      1.500000     0.200000
# 75%         5.20000     3.675000      1.575000     0.300000
# max         5.80000     4.400000      1.900000     0.600000
#
# versicolor ======================================
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# ...

# %%
#이상치 제거하기
import numpy as np
s=df[df.species=="setosa"]["sepal_width"]
q3=np.percentile(s.values,75)
q3
# Out:
# 3.6750000000000003

# %%
setosa25=setosa.quantile(q=0.25, axis=0)
setosa75=setosa.quantile(q=0.75, axis=0)
versicolor25=versicolor.quantile(q=0.25, axis=0)
versicolor75=versicolor.quantile(q=0.75, axis=0)
virginica25=virginica.quantile(q=0.25, axis=0)
virginica75=virginica.quantile(q=0.75, axis=0)

# %%
setosa25 - 1.5 * (setosa75 - setosa25)
# Out:
# sepal_length    4.2000
# sepal_width     2.4875
# petal_length    1.1375
# petal_width     0.0500
# dtype: float64

# %%
setosa75 + 1.5 * (setosa75 - setosa25)
# Out:
# sepal_length    5.8000
# sepal_width     4.3875
# petal_length    1.8375
# petal_width     0.4500
# dtype: float64

# %%
#이상치
def dropsetosa(x):
  if setosa25 - 1.5 * (setosa75 - setosa25)> x:
    x.drop()
  elif setosa75 + 1.5 * (setosa75 - setosa25)< x:
    x.drop()
  else:
    return x

# %%
def dropversicolor(x):
  if versicolor25 - 1.5 * (versicolor75 - versicolor25)> x:
    x.drop()
  elif versicolor75 + 1.5 * (versicolor75 - versicolor25)< x:
    x.drop()
  else:
    return x

# %%
def dropvirginica(x):
  if virginica25 - 1.5 * (virginica75 - virginica25)> x:
    x.drop()
  elif virginica75 + 1.5 * (virginica75 - virginica25)< x:
    x.drop()
  else:
    return x

# %%
#이다음에 못하겠어요 ㅠㅠ
#np.nan은 변수를 제거 하는 함수

# %%
setosa[setosa25 - 1.5 * (setosa75 - setosa25)> setosa]=np.nan
# Out:
# <ipython-input-270-ddfd151f73e9>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   setosa[setosa25 - 1.5 * (setosa75 - setosa25)> setosa]=np.nan
# <ipython-input-270-ddfd151f73e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   setosa[setosa25 - 1.5 * (setosa75 - setosa25)> setosa]=np.nan
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3718: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
setosa[setosa75 + 1.5 * (setosa75 - setosa25)< setosa]=np.nan
# Out:
# <ipython-input-271-36587ec28faa>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   setosa[setosa75 + 1.5 * (setosa75 - setosa25)< setosa]=np.nan
# <ipython-input-271-36587ec28faa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   setosa[setosa75 + 1.5 * (setosa75 - setosa25)< setosa]=np.nan

# %%
versicolor[versicolor25 - 1.5 * (versicolor75 - versicolor25)> versicolor]=np.nan
# Out:
# <ipython-input-273-c53e49c8bd0e>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   versicolor[versicolor25 - 1.5 * (versicolor75 - versicolor25)> versicolor]=np.nan
# <ipython-input-273-c53e49c8bd0e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   versicolor[versicolor25 - 1.5 * (versicolor75 - versicolor25)> versicolor]=np.nan

# %%
versicolor[versicolor75 + 1.5 * (versicolor75 - versicolor25)< versicolor]=np.nan
# Out:
# <ipython-input-272-0d1d99c80997>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   versicolor[versicolor75 + 1.5 * (versicolor75 - versicolor25)< versicolor]=np.nan
# <ipython-input-272-0d1d99c80997>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   versicolor[versicolor75 + 1.5 * (versicolor75 - versicolor25)< versicolor]=np.nan

# %%
virginica[virginica25 - 1.5 * (virginica75 - virginica25)> virginica]=np.nan
# Out:
# <ipython-input-274-4561687f3605>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   virginica[virginica25 - 1.5 * (virginica75 - virginica25)> virginica]=np.nan
# <ipython-input-274-4561687f3605>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   virginica[virginica25 - 1.5 * (virginica75 - virginica25)> virginica]=np.nan

# %%
virginica[virginica75 + 1.5 * (virginica75 - virginica25)< virginica]=np.nan
# Out:
# <ipython-input-275-2db9cc6722a7>:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   virginica[virginica75 + 1.5 * (virginica75 - virginica25)< virginica]=np.nan
# <ipython-input-275-2db9cc6722a7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   virginica[virginica75 + 1.5 * (virginica75 - virginica25)< virginica]=np.nan

# %%
setosa.dropna()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
versicolor.dropna()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
virginica.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# 101           5.8          2.7           5.1          1.9  virginica
# 102           7.1          3.0           5.9          2.1  virginica
# 103           6.3          2.9           5.6          1.8  virginica
# 104           6.5          3.0           5.8          2.2  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 107           7.3          2.9           6.3          1.8  virginica
# 108           6.7          2.5           5.8          1.8  virginica
# 109           7.2          3.6           6.1          2.5  virginica
# 110           6.5          3.2           5.1          2.0  virginica
# 111           6.4          2.7           5.3          1.9  virginica
# 112           6.8          3.0           5.5          2.1  virginica
# 113           5.7          2.5           5.0          2.0  virginica
# ...

# %%
for species in df.species.unique():
  for feature in df.columns[:-1]: #-1인 이유는 젤 마지막 컬럼이 species라서
    s=df[df.species==species][feature]
    outlier, new_mean, new_std=get_new_stat(s)
    d={"species": species, "feature": feature, "outlier의 갯수": outlier, "평균": new_mean, "std": new_std}
    line.append(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-285-7fc25dca84f2> in <module>
#       2   for feature in df.columns[:-1]: #-1인 이유는 젤 마지막 컬럼이 species라서
#       3     s=df[df.species==species][feature]
# ----> 4     outlier, new_mean, new_std=get_new_stat(s)
#       5     d={"species": species, "feature": feature, "outlier의 갯수": outlier, "평균": new_mean, "std": new_std}
#       6     line.append(d)
#
# NameError: name 'get_new_stat' is not defined

# %%
df.loc["setosa"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-288-34cb46fc3de4> in <module>
# ----> 1 df.loc["setosa"]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
# ...

# %%
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
category1=titanic[["age","sex"]]
category1
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
titanic.apply(lambda x: x.sex if x.age>=20 else "child", axis=1)
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887     child
# 888    female
# 889      male
# 890      male
# Length: 891, dtype: object

# %%
category1.loc[category1["age"]<20]="child"
category1
#이것도 좀 이상해요...
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#        age     sex
# 0     22.0    male
# 1     38.0  female
# 2     26.0  female
# 3     35.0  female
# 4     35.0    male
# ..     ...     ...
# 886   27.0    male
# 887  child   child
# 888    NaN  female
# 889   26.0    male
# 890   32.0    male
#
# [891 rows x 2 columns]

# %%
titanic.age.fillna(titanic.age.mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: age, Length: 891, dtype: float64

# %%
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic["age"].mean()
# Out:
# 29.69911764705882

# %%
titanic["age"]=titanic["age"].fillna(titanic["age"].mean())
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# ...

# %%
#성별 생존율
titanic.groupby("sex")[["survived"]].mean()
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
#선실 별 생존율
titanic.groupby("class")[["survived"]].mean()
# Out:
#         survived
# class
# First   0.629630
# Second  0.472826
# Third   0.242363

# %%
#출발지 별 생존율
titanic.groupby("embark_town")[["survived"]].mean()
# Out:
#              survived
# embark_town
# Cherbourg    0.553571
# Queenstown   0.389610
# Southampton  0.336957

# %%
titanic.pivot_table("survived","class")
# Out:
#         survived
# class
# First   0.629630
# Second  0.472826
# Third   0.242363

# %%
titanic.pivot_table("survived","sex")
# Out:
#         survived
# sex
# female  0.742038
# male    0.188908

# %%
titanic.pivot_table("survived","embark_town")
# Out:
#              survived
# embark_town
# Cherbourg    0.553571
# Queenstown   0.389610
# Southampton  0.336957

# %%
titanic["class"].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
titanic["survived"][titanic["survived"]==1].count()
# Out:
# 342

# %%
(titanic["survived"][titanic["survived"]==1][titanic["class"]=="First"]).count()
# Out:
# 136

# %%
(titanic["survived"][titanic["survived"]==1][titanic["class"]=="Second"]).count()
# Out:
# 87

# %%
(titanic["survived"][titanic["survived"]==1][titanic["class"]=="Third"]).count()
# Out:
# 119

# %%
(titanic["survived"][titanic["survived"]==1][titanic["class"]=="First"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.39766081871345027

# %%
(titanic["survived"][titanic["survived"]==1][titanic["class"]=="Second"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.2543859649122807

# %%
(titanic["survived"][titanic["survived"]==1][titanic["class"]=="Third"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.347953216374269

# %%
titanic["sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
(titanic["survived"][titanic["survived"]==1][titanic["sex"]=="male"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.31871345029239767

# %%
(titanic["survived"][titanic["survived"]==1][titanic["sex"]=="female"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.6812865497076024

# %%
titanic["embark_town"].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
(titanic["survived"][titanic["survived"]==1][titanic["embark_town"]=="Southampton"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.6345029239766082

# %%
(titanic["survived"][titanic["survived"]==1][titanic["embark_town"]=="Cherbourg"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.2719298245614035

# %%
(titanic["survived"][titanic["survived"]==1][titanic["embark_town"]=="Queenstown"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.08771929824561403

# %%
(titanic["survived"][titanic["survived"]==1][titanic["embark_town"]=="nan"]).count()/titanic["survived"][titanic["survived"]==1].count()
# Out:
# 0.0

# %%
#타이타닉호 승객을 ‘미성년자’, ‘청년’, ‘중년’, ‘장년’, ‘노년’ 나이 그룹으로 나누고,
#각 그룹별 생존율을 구하시오.



bins = [1, 20, 30, 50, 70, 100]
labels = ["미성년자", "청년", "중년", "장년", "노년"]

# %%
titanic["age_category"]=pd.cut(titanic.age, bins, labels=labels)
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone age_category
# ...

# %%
titanic.age_category.value_counts()
# Out:
# 청년      407
# 중년      241
# 미성년자    165
# 장년       59
# 노년        5
# Name: age_category, dtype: int64

# %%
titanic.pivot_table("survived","age_category")
# Out:
#               survived
# age_category
# 미성년자          0.424242
# 청년            0.334152
# 중년            0.423237
# 장년            0.355932
# 노년            0.200000

# %%
titanic["age_group"]=pd.qcut(titanic.age, 3, labels=["a1", "a2", "a3"])
titanic
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone age_category  \
# ...

# %%
mpg=sns.load_dataset('mpg')
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mpg["hp_per_cc"]=mpg["horsepower"]/mpg["displacement"]

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  hp_per_cc
# 0            70     usa  chevrolet chevelle malibu   0.423453
# ...

# %%
mpg["name"]
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 393              ford mustang gl
# 394                    vw pickup
# 395                dodge rampage
# 396                  ford ranger
# 397                   chevy s-10
# Name: name, Length: 398, dtype: object

# %%
mpg["manufacturer"]=mpg.name.apply(lambda x: x.split()[0])
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  hp_per_cc manufacturer
# ...

# %%
mpg.name.apply(lambda x: x.split()[1::])
# Out:
# 0      [chevelle, malibu]
# 1          [skylark, 320]
# 2             [satellite]
# 3            [rebel, sst]
# 4                [torino]
#               ...
# 393         [mustang, gl]
# 394              [pickup]
# 395             [rampage]
# 396              [ranger]
# 397                [s-10]
# Name: name, Length: 398, dtype: object

# %%
mpg["model"]=mpg.name.apply(lambda x: " ".join(x.split()[1:]))
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  hp_per_cc manufacturer  \
# ...

# %%
mpg["mpg"].groupby(mpg["cylinders"]).mean()
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64

# %%
mpg.groupby("cylinders")[["mpg"]].mean()
# Out:
#                  mpg
# cylinders
# 3          20.550000
# 4          29.286765
# 5          27.366667
# 6          19.985714
# 8          14.963107

# %%
mpg.pivot_table("mpg","cylinders")
# Out:
#                  mpg
# cylinders
# 3          20.550000
# 4          29.286765
# 5          27.366667
# 6          19.985714
# 8          14.963107

# %%
mpg["hp_per_cc"].groupby(mpg["origin"]).mean()
# Out:
# origin
# europe    0.740005
# japan     0.789485
# usa       0.512063
# Name: hp_per_cc, dtype: float64

# %%
mpg.groupby("origin")[["hp_per_cc"]].mean()
# Out:
#         hp_per_cc
# origin
# europe   0.740005
# japan    0.789485
# usa      0.512063

# %%
mpg.pivot_table("hp_per_cc","origin")
# Out:
#         hp_per_cc
# origin
# europe   0.740005
# japan    0.789485
# usa      0.512063

# %%
s=mpg.manufacturer.value_counts()
s[s>=5]
# Out:
# ford          51
# chevrolet     43
# plymouth      31
# amc           28
# dodge         28
# toyota        25
# datsun        23
# buick         17
# pontiac       16
# volkswagen    15
# honda         13
# mercury       11
# mazda         10
# oldsmobile    10
# fiat           8
# peugeot        8
# audi           7
# chrysler       6
# vw             6
# volvo          6
# renault        5
# Name: manufacturer, dtype: int64

# %%
s[s>=5].index
# Out:
# Index(['ford', 'chevrolet', 'plymouth', 'amc', 'dodge', 'toyota', 'datsun',
#        'buick', 'pontiac', 'volkswagen', 'honda', 'mercury', 'mazda',
#        'oldsmobile', 'fiat', 'peugeot', 'audi', 'chrysler', 'vw', 'volvo',
#        'renault'],
#       dtype='object')

# %%
type(s[s>=5].index)
# Out:
# pandas.core.indexes.base.Index

# %%
big=s[s>=5].index.tolist()
type(big)
# Out:
# list

# %%
#mpg데이터에서 big에 속한 것만 가져오기 (필터링)
mpg.manufacturer.isin(big)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 393     True
# 394     True
# 395     True
# 396     True
# 397    False
# Name: manufacturer, Length: 398, dtype: bool

# %%
bigbig=mpg[mpg.manufacturer.isin(big)]
bigbig
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
#
#      model_year  origin                       name  hp_per_cc manufacturer  \
# ...

# %%
bigbig.pivot_table("mpg","manufacturer").sort_values(by="mpg", ascending=False).head()
# Out:
#                     mpg
# manufacturer
# vw            39.016667
# honda         33.761538
# renault       32.880000
# datsun        31.113043
# mazda         30.860000
