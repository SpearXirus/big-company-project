# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone 연령대
# 0    man        True  NaN  Southampton    no  False  청년
# 1  woman       False    C    Cherbourg   yes  False  중년

# %%
titanic = titanic.loc[:, ['sex', 'age', 'class', 'embark_town', 'survived', ]]

# %%
titanic = titanic.dropna(subset=['age'], how='any', axis=0)

# %%
# 3-c
df = titanic.loc[:, ['sex', 'class', 'embark_town', 'survived']]
df_sex_avg = df.pivot_table(columns='sex', aggfunc='mean')
df_sex_avg
# Out:
# sex         female      male
# survived  0.754789  0.205298

# %%
df_class_avg = df.pivot_table(columns='class', aggfunc='mean')
df_class_avg
# Out:
# class        First    Second     Third
# survived  0.655914  0.479769  0.239437

# %%
df_embark_town_avg = df.pivot_table(columns='embark_town', aggfunc='mean')
df_embark_town_avg
# Out:
# embark_town  Cherbourg  Queenstown  Southampton
# survived      0.607692    0.285714     0.362816

# %%
# 3-d
titanic['연령대'] = pd.cut(x=titanic['age'], # 데이터 배열
                      bins=[1, 20, 30, 50, 70, 100], # 경계값
                      labels=['미성년자', '청년', '중년', '장년', '노년'], # bin이름
                      include_lowest=True)
titanic.head(4)
# Out:
#       sex   age  class  embark_town  survived 연령대
# 0    male  22.0  Third  Southampton         0  청년
# 1  female  38.0  First    Cherbourg         1  중년
# 2  female  26.0  Third  Southampton         1  청년
# 3  female  35.0  First  Southampton         1  중년

# %%
titanic['age_group'] = pd.qcut(titanic['age'],3)

# %%
# Out:
# <bound method NDFrame.describe of 0      (0.419, 23.0]
# 1       (34.0, 80.0]
# 2       (23.0, 34.0]
# 3       (34.0, 80.0]
# 4       (34.0, 80.0]
#            ...
# 885     (34.0, 80.0]
# 886     (23.0, 34.0]
# 887    (0.419, 23.0]
# 889     (23.0, 34.0]
# 890     (23.0, 34.0]
# Name: age, Length: 714, dtype: category
# Categories (3, interval[float64, right]): [(0.419, 23.0] < (23.0, 34.0] < (34.0, 80.0]]>
